# %%
# Mount drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/PBL6_Code/dataset.zip

# %% [markdown]
# # 1. Load data

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers

import warnings
warnings.filterwarnings('ignore')

# %%
class DataGenerator():
    def __init__(self, batch_size, target_size=(256, 256)):
        self.batch_size = batch_size
        self.target_size = target_size

    def generate_data(self, subset, directory):

        print("Loading", subset, "...")

        shuffle = False
        if subset == 'train' or subset == 'validation':
            shuffle = True

        dataset = tf.keras.preprocessing.image_dataset_from_directory(
            directory,
            labels='inferred',
            label_mode='categorical',
            class_names=['0', '1'],
            color_mode='rgb',
            batch_size=self.batch_size,
            image_size=self.target_size,
            shuffle=shuffle,
            seed=42,
        )

        return dataset

# %%
def augmentation_layer(dataset):
    data_augmentation = tf.keras.Sequential(
        [
            tf.keras.layers.RandomFlip('horizontal'),
            tf.keras.layers.RandomContrast(0.2),
            tf.keras.layers.RandomBrightness(0.2),
        ]
    )
    dataset = dataset.map(lambda x, y: (data_augmentation(x, training=True), y))
    return dataset

# %%
batch_size = 256
target_size = (256, 256)
data_gen = DataGenerator(batch_size, target_size)

train_set = data_gen.generate_data('train', '/content/dataset/train')
val_set = data_gen.generate_data('validation', '/content/dataset/validate')
test_set = data_gen.generate_data('test', '/content/dataset/test')
# Out:
# Loading train ...
# Found 72574 files belonging to 2 classes.
# Loading validation ...
# Found 24190 files belonging to 2 classes.
# Loading test ...
# Found 24190 files belonging to 2 classes.

# %%
# get labels for evaluating step
labels = np.array([])
for x, y in test_set:
    labels = np.concatenate([labels, np.argmax(y.numpy(), axis=-1)])

print(len(labels))
# Out:
# 24190

# %%
train_set = augmentation_layer(train_set)

# %% [markdown]
# # 2. Define model/trainer/evaluator

# %% [markdown]
# ## 2.1. Model class

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Dropout
from tensorflow.keras.applications import MobileNetV3Large, EfficientNetB2

from tensorflow.keras.utils import plot_model
from IPython.display import Image


class CustomModels:
    """Custom Model Class"""

    def __init__(self, num_classes=1000, input_shape=(256, 256, 3), name='resnet'):
        self.num_classes = num_classes
        self.input_shape = input_shape
        self.name = name
        self.model = None

    def build(self):
        if "mobilenet" in self.name:
            base_model = MobileNetV3Large(include_top=False, weights='imagenet')

        elif "efficientnet" in self.name:
            base_model = EfficientNetB2(include_top=False, weights='imagenet')

        for layer in base_model.layers:
            layer.trainable = False

        inputs = Input(shape=self.input_shape)
        x = base_model(inputs, training=False)
        x = GlobalAveragePooling2D()(x)
        x = Dropout(0.1)(x)
        x = Dense(units=2048, activation='relu')(x)
        outputs = Dense(units=self.num_classes, activation='softmax')(x)
        model = Model(inputs=inputs, outputs=outputs, name=self.name)

        self.model = model
        return model

    def visualize(self):
        plot_model(self.model, show_shapes=True, to_file=self.name + '.png')
        image = Image(self.name + '.png')
        display(image)

    def summary(self):
        print(self.model.summary(show_trainable=True))

# %% [markdown]
# # 2.2 Define trainer

# %%
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import os


class Trainer:
    def __init__(
        self, model, loss, optimizer=Adam(learning_rate=0.001), metrics=['accuracy']
    ):
        self.model = model
        self.optimizer = optimizer
        self.loss = loss
        self.metrics = metrics
        self.history = None
        self.epochs = 0
        self.fine_tune_epochs = 0

    def compile(self):
        """
        Method to compile model with optimizer, loss and metrics
        """
        self.model.compile(
            optimizer=self.optimizer, loss=self.loss, metrics=self.metrics
        )

    def fit(self, train_set, val_set, batch_size, epochs, callbacks=[]):
        """
        Method to train model with dataset and return history
        """
        train_history = self.model.fit(
            train_set,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=val_set,
            callbacks=callbacks,
        )
        # history
        self.history = train_history.history
        self.epochs = len(train_history.history['val_loss'])

    def get_model_info(self):
        """Method to print all informations of model"""
        print("- Model name: ", self.model.name)
        print("- Number of layers: ", len(self.model.layers))
        print("- Base model name: ", self.model.layers[1].name)
        print("- Number of layers of base model: ", len(self.model.layers[1].layers))
        print("- Number of parameters: ", self.model.count_params())

    def fine_tune(
        self,
        train_set,
        val_set,
        batch_size,
        epochs,
        new_optimizer,
        callbacks=[],
        unfreeze_position=0,
    ):
        """
        Method to fine tune model with dataset and return history
        """
        # unfreeze layers
        for layer in self.model.layers[1].layers[unfreeze_position:]:
            if not isinstance(layer, layers.BatchNormalization):
                layer.trainable = True

        # recompile model
        self.model.compile(
            optimizer=new_optimizer, loss=self.loss, metrics=self.metrics
        )

        print("------------")
        print(
            f"Unfreezed from position {unfreeze_position} to {len(self.model.layers[1].layers) - 1}"
        )
        print(self.model.summary(show_trainable=True))

        output_file = "/content/finetune_layer_info.txt"
        with open(output_file, "w") as f:
            for i, layer in enumerate(self.model.layers[1].layers):
                f.write(f"{i} {layer.name} {layer.trainable}\n")
        print("------------")
        # print total trainable param of basemodel
        total_trainable_param = 0
        for layer in self.model.layers[1].layers:
            if layer.trainable:
                total_trainable_param += layer.count_params()
        print(f"Total trainable param of base model: {total_trainable_param}")

        # fine tune model
        fine_tune_history = self.model.fit(
            train_set,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=val_set,
            callbacks=callbacks,
        )

        # add fine tune history to train history
        self.history['accuracy'] += fine_tune_history.history['accuracy']
        self.history['loss'] += fine_tune_history.history['loss']
        self.history['val_accuracy'] += fine_tune_history.history['val_accuracy']
        self.history['val_loss'] += fine_tune_history.history['val_loss']

        epochs = len(fine_tune_history.history['val_loss'])
        self.epochs += epochs
        self.fine_tune_epochs += epochs

    def plot_history(self):
        """
        Method to plot model training history
        """

        fig, axes = plt.subplots(2, 1, figsize=(16, 8), sharex=True)

        axes[0].plot(self.history['accuracy'])
        axes[0].plot(self.history['val_accuracy'])
        # draw line at fine tune position
        if self.fine_tune_epochs > 0:
            axes[0].axvline(
                x=self.epochs - self.fine_tune_epochs, color='red', linestyle='--'
            )

        axes[0].set_ylabel('Accuracy')

        axes[1].plot(self.history['loss'])
        axes[1].plot(self.history['val_loss'])

        # draw line at fine tune position
        if self.fine_tune_epochs > 0:
            axes[1].axvline(
                x=self.epochs - self.fine_tune_epochs, color='red', linestyle='--'
            )

        axes[1].set_xlabel('Epoch')
        axes[1].set_ylabel('Loss')

        fig.suptitle('Model performance during training')
        axes[0].legend(('Train accuracy', 'Validation accuracy'))
        axes[1].legend(('Train loss', 'Validation loss'))

    def save_model(self, path='/content/drive/MyDrive/new_saved_model'):
        """
        Method to save model after training
        """
        save_path = os.path.join(path, f'{self.model.name}.h5')
        self.model.save(save_path)
        return save_path

# %% [markdown]
# # 2.3 Define evaluator

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import classification_report


class Evaluator:

    def __init__(self, model, test_set, y_true):
        self.model = model

        self.test_loss, self.test_acc = self.model.evaluate(
            test_set, verbose=1)

        y_pred = self.model.predict(test_set)
        y_pred = np.argmax(y_pred, axis=1)

        self.cm = confusion_matrix(y_true, y_pred)

        self.report = classification_report(y_true, y_pred)

    def evaluate(self):
        """
        Method to evaluate model and return loss and accuracy
        """
        return self.test_loss, self.test_acc

    def confusion_matrix(self):
        """
        Method to plot confusion matrix
        """
        sns.heatmap(self.cm, annot=True, fmt="d")
        plt.show()

    def classification_report(self):
        """
        Method to print classification report on test set
        """
        print(self.report)

# %% [markdown]
# # 3. Train/Test model

# %% [markdown]
# ## 3.1. Create model

# %%
custom_model = CustomModels(
    num_classes=2, input_shape=(256, 256, 3), name='mobilenet_new_50_12'
)
custom_model.build()
custom_model.visualize()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step

# %%
custom_model.summary()
# Out:
# Model: "mobilenet_new_50_12"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0         Y
#
#  MobilenetV3large (Function  (None, None, None, 960)   2996352   Y
#  al)
#
#  global_average_pooling2d (  (None, 960)               0         Y
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 960)               0         Y
#
#  dense (Dense)               (None, 2048)              1968128   Y
#
#  dense_1 (Dense)             (None, 2)                 4098      Y
#
# ============================================================================
# Total params: 4968578 (18.95 MB)
# Trainable params: 1972226 (7.52 MB)
# Non-trainable params: 2996352 (11.43 MB)
# ____________________________________________________________________________
# None

# %% [markdown]
# ## 3.2. Train model

# %%
# Define hyperparameters for model trainer
import math
import os

epochs = 30
batch_size = 256

metrics = ['accuracy']
loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)

initial_learning_rate = 0.01
optimizer = tf.keras.optimizers.Adam(initial_learning_rate)

def lr_step_decay(epoch, lr):
    drop_rate = 0.5
    epochs_drop = 5.0
    return initial_learning_rate * math.pow(drop_rate, math.floor(epoch / epochs_drop))

checkpoint_filepath = os.path.join(
    '/content/drive/MyDrive/checkpoints',
    custom_model.model.name,
    "training",
    "{epoch:03d}-{val_loss:.4f}.h5",
)

os.makedirs(checkpoint_filepath, exist_ok=True)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', mode='min', verbose=1, patience=10
)
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lr_step_decay, verbose=1)

# %%
# Compile and train model
trainer = Trainer(custom_model.model, loss, optimizer, metrics)

# Compile model
trainer.compile()

# Train model
trainer.fit(train_set=train_set, val_set=val_set, batch_size=batch_size, epochs=epochs, callbacks=[lr_schedule, early_stopping, checkpoint])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/30
# 284/284 [==============================] - 231s 760ms/step - loss: 0.6042 - accuracy: 0.7955 - val_loss: 0.3795 - val_accuracy: 0.8347 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/30
# 284/284 [==============================] - 222s 779ms/step - loss: 0.3913 - accuracy: 0.8267 - val_loss: 0.3634 - val_accuracy: 0.8432 - lr: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/30
# 284/284 [==============================] - 219s 764ms/step - loss: 0.3741 - accuracy: 0.8339 - val_loss: 0.3757 - val_accuracy: 0.8335 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/30
# 284/284 [==============================] - 222s 778ms/step - loss: 0.3644 - accuracy: 0.8401 - val_loss: 0.3525 - val_accuracy: 0.8468 - lr: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/30
# 284/284 [==============================] - 219s 766ms/step - loss: 0.3563 - accuracy: 0.8439 - val_loss: 0.3462 - val_accuracy: 0.8491 - lr: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.005.
# Epoch 6/30
# 284/284 [==============================] - 215s 754ms/step - loss: 0.3426 - accuracy: 0.8507 - val_loss: 0.3432 - val_accuracy: 0.8512 - lr: 0.0050
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.005.
# Epoch 7/30
# 284/284 [==============================] - 215s 755ms/step - loss: 0.3339 - accuracy: 0.8552 - val_loss: 0.3489 - val_accuracy: 0.8493 - lr: 0.0050
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.005.
# Epoch 8/30
# 284/284 [==============================] - 220s 771ms/step - loss: 0.3312 - accuracy: 0.8573 - val_loss: 0.3348 - val_accuracy: 0.8582 - lr: 0.0050
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.005.
# Epoch 9/30
# 284/284 [==============================] - 212s 744ms/step - loss: 0.3235 - accuracy: 0.8592 - val_loss: 0.3347 - val_accuracy: 0.8601 - lr: 0.0050
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.005.
# Epoch 10/30
# 284/284 [==============================] - 216s 755ms/step - loss: 0.3240 - accuracy: 0.8594 - val_loss: 0.3295 - val_accuracy: 0.8600 - lr: 0.0050
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 11/30
# 284/284 [==============================] - 219s 765ms/step - loss: 0.3099 - accuracy: 0.8669 - val_loss: 0.3366 - val_accuracy: 0.8592 - lr: 0.0025
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 12/30
# 284/284 [==============================] - 219s 768ms/step - loss: 0.3049 - accuracy: 0.8696 - val_loss: 0.3336 - val_accuracy: 0.8620 - lr: 0.0025
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 13/30
# 284/284 [==============================] - 215s 754ms/step - loss: 0.3037 - accuracy: 0.8692 - val_loss: 0.3355 - val_accuracy: 0.8591 - lr: 0.0025
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 14/30
# 284/284 [==============================] - 216s 758ms/step - loss: 0.2984 - accuracy: 0.8707 - val_loss: 0.3337 - val_accuracy: 0.8610 - lr: 0.0025
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 15/30
# 284/284 [==============================] - 215s 754ms/step - loss: 0.2961 - accuracy: 0.8718 - val_loss: 0.3328 - val_accuracy: 0.8611 - lr: 0.0025
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 16/30
# 284/284 [==============================] - 220s 769ms/step - loss: 0.2882 - accuracy: 0.8762 - val_loss: 0.3287 - val_accuracy: 0.8602 - lr: 0.0012
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 17/30
# 284/284 [==============================] - 218s 763ms/step - loss: 0.2864 - accuracy: 0.8763 - val_loss: 0.3290 - val_accuracy: 0.8624 - lr: 0.0012
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 18/30
# 284/284 [==============================] - 214s 750ms/step - loss: 0.2859 - accuracy: 0.8775 - val_loss: 0.3290 - val_accuracy: 0.8624 - lr: 0.0012
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 19/30
# 284/284 [==============================] - 216s 756ms/step - loss: 0.2817 - accuracy: 0.8793 - val_loss: 0.3326 - val_accuracy: 0.8619 - lr: 0.0012
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 20/30
# 284/284 [==============================] - 216s 757ms/step - loss: 0.2817 - accuracy: 0.8791 - val_loss: 0.3296 - val_accuracy: 0.8621 - lr: 0.0012
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 21/30
# 284/284 [==============================] - 218s 765ms/step - loss: 0.2772 - accuracy: 0.8812 - val_loss: 0.3273 - val_accuracy: 0.8629 - lr: 6.2500e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 22/30
# 284/284 [==============================] - 216s 756ms/step - loss: 0.2731 - accuracy: 0.8838 - val_loss: 0.3274 - val_accuracy: 0.8618 - lr: 6.2500e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 23/30
# 284/284 [==============================] - 215s 753ms/step - loss: 0.2756 - accuracy: 0.8820 - val_loss: 0.3321 - val_accuracy: 0.8618 - lr: 6.2500e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 24/30
# 284/284 [==============================] - 219s 766ms/step - loss: 0.2727 - accuracy: 0.8827 - val_loss: 0.3283 - val_accuracy: 0.8621 - lr: 6.2500e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 25/30
# 284/284 [==============================] - 219s 769ms/step - loss: 0.2715 - accuracy: 0.8836 - val_loss: 0.3288 - val_accuracy: 0.8629 - lr: 6.2500e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 26/30
# 284/284 [==============================] - 220s 771ms/step - loss: 0.2714 - accuracy: 0.8848 - val_loss: 0.3255 - val_accuracy: 0.8631 - lr: 3.1250e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 27/30
# 284/284 [==============================] - 218s 763ms/step - loss: 0.2679 - accuracy: 0.8852 - val_loss: 0.3262 - val_accuracy: 0.8632 - lr: 3.1250e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 28/30
# 284/284 [==============================] - 217s 760ms/step - loss: 0.2682 - accuracy: 0.8844 - val_loss: 0.3271 - val_accuracy: 0.8628 - lr: 3.1250e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 29/30
# 284/284 [==============================] - 216s 756ms/step - loss: 0.2663 - accuracy: 0.8867 - val_loss: 0.3271 - val_accuracy: 0.8635 - lr: 3.1250e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 30/30
# 284/284 [==============================] - 216s 756ms/step - loss: 0.2669 - accuracy: 0.8863 - val_loss: 0.3276 - val_accuracy: 0.8632 - lr: 3.1250e-04

# %%
trainer.plot_history()

# %%
evaluate = Evaluator(trainer.model, test_set, labels)
# Out:
# 95/95 [==============================] - 15s 155ms/step - loss: 0.3330 - accuracy: 0.8618
# 95/95 [==============================] - 15s 151ms/step

# %%
evaluate.confusion_matrix()

# %%
evaluate.classification_report()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.93      0.89     14000
#          1.0       0.89      0.76      0.82     10190
#
#     accuracy                           0.86     24190
#    macro avg       0.87      0.85      0.85     24190
# weighted avg       0.86      0.86      0.86     24190

# %% [markdown]
# ## 3.3. Fine-tuning model

# %%
trainer.get_model_info()
# Out:
# - Model name:  mobilenet_new_50_12
# - Number of layers:  6
# - Base model name:  MobilenetV3large
# - Number of layers of base model:  263
# - Number of parameters:  4968578

# %%
# Define hyperparameters for finetuning
import os
import math

epochs = 12
batch_size = 256


metrics = ['accuracy']
loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)

initial_learning_rate = 0.001
new_optimizer = tf.keras.optimizers.Adam(initial_learning_rate)

def lr_step_decay_2(epoch, lr):
    drop_rate = 0.5
    epochs_drop = 3.0
    return initial_learning_rate * math.pow(drop_rate, math.floor(epoch / epochs_drop))

checkpoint_filepath = os.path.join(
    '/content/drive/MyDrive/checkpoints',
    custom_model.model.name,
    "finetuning",
    "{epoch:03d}-{val_loss:.4f}.h5",

)

os.makedirs(checkpoint_filepath, exist_ok=True)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', mode='min', verbose=1, patience=6
)
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lr_step_decay_2, verbose=1)

# %%
# Fine tune model
trainer.fine_tune(train_set=train_set, val_set=val_set, batch_size=batch_size, epochs=epochs, new_optimizer= new_optimizer,
                  callbacks=[lr_schedule, early_stopping, checkpoint], unfreeze_position=200)
# Out:
# ------------
# Unfreezed from position 200 to 262
# Model: "mobilenet_new_50_12"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0         Y
#
#  MobilenetV3large (Function  (None, None, None, 960)   2996352   Y
#  al)
#
#  global_average_pooling2d (  (None, 960)               0         Y
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 960)               0         Y
#
#  dense (Dense)               (None, 2048)              1968128   Y
#
#  dense_1 (Dense)             (None, 2)                 4098      Y
#
# ============================================================================
# Total params: 4968578 (18.95 MB)
# Trainable params: 4046378 (15.44 MB)
# Non-trainable params: 922200 (3.52 MB)
# ____________________________________________________________________________
# None
# ------------
# Total trainable param of base model: 2074152
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/12
# 284/284 [==============================] - 232s 784ms/step - loss: 0.2623 - accuracy: 0.8928 - val_loss: 0.1422 - val_accuracy: 0.9443 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/12
# 284/284 [==============================] - 216s 756ms/step - loss: 0.1173 - accuracy: 0.9564 - val_loss: 0.1052 - val_accuracy: 0.9602 - lr: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/12
# 284/284 [==============================] - 224s 784ms/step - loss: 0.0751 - accuracy: 0.9720 - val_loss: 0.0903 - val_accuracy: 0.9689 - lr: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 4/12
# 284/284 [==============================] - 220s 771ms/step - loss: 0.0363 - accuracy: 0.9866 - val_loss: 0.0825 - val_accuracy: 0.9749 - lr: 5.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 5/12
# 284/284 [==============================] - 219s 769ms/step - loss: 0.0265 - accuracy: 0.9905 - val_loss: 0.0784 - val_accuracy: 0.9759 - lr: 5.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 6/12
# 284/284 [==============================] - 213s 747ms/step - loss: 0.0216 - accuracy: 0.9921 - val_loss: 0.0923 - val_accuracy: 0.9746 - lr: 5.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 7/12
# 284/284 [==============================] - 222s 776ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0873 - val_accuracy: 0.9790 - lr: 2.5000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 8/12
# 284/284 [==============================] - 215s 752ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0847 - val_accuracy: 0.9778 - lr: 2.5000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 9/12
# 284/284 [==============================] - 222s 777ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0786 - val_accuracy: 0.9804 - lr: 2.5000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.000125.
# Epoch 10/12
# 284/284 [==============================] - 221s 774ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0820 - val_accuracy: 0.9811 - lr: 1.2500e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.000125.
# Epoch 11/12
# 284/284 [==============================] - 223s 780ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0948 - val_accuracy: 0.9799 - lr: 1.2500e-04
# Epoch 11: early stopping

# %%
trainer.plot_history()

# %% [markdown]
# ## 3.4. Evaluate model

# %%
evaluate = Evaluator(trainer.model, test_set, labels)
# Out:
# 95/95 [==============================] - 15s 157ms/step - loss: 0.0937 - accuracy: 0.9791
# 95/95 [==============================] - 16s 152ms/step

# %%
evaluate.confusion_matrix()

# %%
evaluate.classification_report()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98     14000
#          1.0       0.99      0.96      0.97     10190
#
#     accuracy                           0.98     24190
#    macro avg       0.98      0.98      0.98     24190
# weighted avg       0.98      0.98      0.98     24190

# %% [markdown]
# ## 3.5. Save model

# %%
trainer.save_model()
# Out:
# '/content/drive/MyDrive/new_saved_model/mobilenet_new_50_12.h5'

# %% [markdown]
# # 4. Inference

# %%
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array
from keras.models import load_model


def preprocess_image(image_path, target_size=(256, 256)):
    img = load_img(image_path, target_size=target_size)
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    return x


def predict_image(image_data, model_path):
    model = load_model(model_path, compile=False)
    prediction = model.predict(image_data)
    print(prediction)
    predicted_class = np.argmax(prediction)

    if predicted_class == 0:
        predicted_label = "real"
    else:
        predicted_label = "fake"

    return predicted_label

# %%
# download a fake image to test
from IPython.display import Image
import requests

URL = "https://cbsaustin.com/resources/media/8b2d4079-8b82-465b-9514-8da9af8d5b49-full1x1_AP23326229180956.jpg"
response = requests.get(URL)

image_name = 'real.png'

with open(image_name, "wb") as f:
    f.write(response.content)

image = Image(image_name)
display(image)

# %%
# Preprocess image
image_name = 'real.png'
image = preprocess_image(image_name)
model_path = '/content/drive/MyDrive/new_saved_model/mobilenet_new_50_12.h5'
predicted_class = predict_image(image, model_path)
print("Predicted class:", predicted_class)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[1.000000e+00 2.133447e-17]]
# Predicted class: real

# %%
# download a fake image to test
from IPython.display import Image
import requests
URL = "https://thispersondoesnotexist.com/"
response = requests.get(URL)

image_name = 'fake.png'

with open(image_name, "wb") as f:
    f.write(response.content)

image = Image(image_name)
display(image)

# %%
# Preprocess image
image_name = 'fake.png'
image = preprocess_image(image_name)
model_path = '/content/drive/MyDrive/new_saved_model/mobilenet_new_50_12.h5'
predicted_class = predict_image(image, model_path)
print("Predicted class:", predicted_class)
# Out:
# WARNING:tensorflow:5 out of the last 99 calls to <function Model.make_predict_function.<locals>.predict_function at 0x79ecd7419630> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# [[5.598086e-20 1.000000e+00]]
# Predicted class: fake
